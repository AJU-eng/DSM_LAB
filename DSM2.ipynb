# %%
import pandas as pd
a={'rollno':[1,2,3],'name':['adi','abhi','abu']}
print(a)
# Out:
# {'rollno': [1, 2, 3], 'name': ['adi', 'abhi', 'abu']}

# %%
import pandas as pd
a={'rollno':[1,2,3],'name':['adi','abhi','abu']}

b=pd.DataFrame(a)
print(b)
# Out:
#    rollno  name
# 0       1   adi
# 1       2  abhi
# 2       3   abu

# %%
import pandas as pd
a=[1,2,3,4]
b=pd.Series(a,index=["w","x","y","z"])
print(b)
# Out:
# w    1
# x    2
# y    3
# z    4
# dtype: int64

# %%
import pandas as pd
a={'rollno':[1,2,3],'name':['adi','abhi','abu']}

b=pd.DataFrame(a)
print(b.loc[0])
# Out:
# rollno      1
# name      adi
# Name: 0, dtype: object

# %%
import pandas as pd
a=pd.read_csv('modified_data.csv')
print(a.head(3))
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-05-02   313000.0       3.0        1.5         1340      7912     1.5
# 1  2014-05-02  2384000.0       5.0        2.5         3650      9050     2.0
# 2  2014-05-02   342000.0       3.0        2.0         1930     11947     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1340              0      1955
# 1           0     4          5        3370            280      1921
# 2           0     0          4        1930              0      1966
#
#    yr_renovated                    street       city  statezip  price_per_sqft
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133          233.58
# 1             0           709 W Blaine St    Seattle  WA 98119          653.15
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042          177.20

# %%
import pandas as pd
a=pd.read_csv('modified_data.csv')
print(a.tail(3))
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4597  2014-07-09  416904.17       3.0        2.5         3010      7014
# 4598  2014-07-10  203400.00       4.0        2.0         2090      6630
# 4599  2014-07-10  220600.00       3.0        2.5         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 4597     2.0           0     0          3        3010              0
# 4598     1.0           0     0          3        1070           1020
# 4599     2.0           0     0          4        1490              0
#
#       yr_built  yr_renovated             street       city  statezip  \
# 4597      2009             0   759 Ilwaco Pl NE     Renton  WA 98059
# 4598      1974             0  5148 S Creston St    Seattle  WA 98178
# 4599      1990             0  18717 SE 258th St  Covington  WA 98042
#
#       price_per_sqft
# 4597          138.51
# 4598           97.32
# 4599          148.05

# %%
import pandas as pd
a=pd.read_csv('modified_data.csv')
b=a.dropna()
print(b)
# Out:
#             date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   313000.00       3.0       1.50         1340      7912
# 1     2014-05-02  2384000.00       5.0       2.50         3650      9050
# 2     2014-05-02   342000.00       3.0       2.00         1930     11947
# 3     2014-05-02   420000.00       3.0       2.25         2000      8030
# 4     2014-05-02   550000.00       4.0       2.50         1940     10500
# ...          ...         ...       ...        ...          ...       ...
# 4595  2014-07-09   308166.67       3.0       1.75         1510      6360
# 4596  2014-07-09   534333.33       3.0       2.50         1460      7573
# 4597  2014-07-09   416904.17       3.0       2.50         3010      7014
# 4598  2014-07-10   203400.00       4.0       2.00         2090      6630
# 4599  2014-07-10   220600.00       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
import pandas as pd
a=pd.read_csv('modified_data.csv')
print(a.head(3))
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-05-02   313000.0       3.0        1.5         1340      7912     1.5
# 1  2014-05-02  2384000.0       5.0        2.5         3650      9050     2.0
# 2  2014-05-02   342000.0       3.0        2.0         1930     11947     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1340              0      1955
# 1           0     4          5        3370            280      1921
# 2           0     0          4        1930              0      1966
#
#    yr_renovated                    street       city  statezip  price_per_sqft
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133          233.58
# 1             0           709 W Blaine St    Seattle  WA 98119          653.15
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042          177.20

# %%
import pandas as pd
list=[10,20,30,40,50]
s = pd.Series(list)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
dates=pd.date_range(start='20-11-2024',end='24-11-2024')
print("series of dates:")
print(dates)
# Out:
# series of dates:
# DatetimeIndex(['2024-11-20', '2024-11-21', '2024-11-22', '2024-11-23',
#                '2024-11-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
data=[[101,'Anu',85],[102,'Binu',90],[103,'Cathy',70]]
df=pd.DataFrame(data,columns=['rollno','name','mark'])
print("Data frame:")
print(df)
# Out:
# Data frame:
#    rollno   name  mark
# 0     101    Anu    85
# 1     102   Binu    90
# 2     103  Cathy    70

# %%
import pandas as pd
data={
    'name':['Anu','Binu','Cathy'],
    'Age':[20,21,22],
    'mark':[85,90,70]
}

df=pd.DataFrame(data)
print('dataFrame')
print(df)
# Out:
# dataFrame
#     name  Age  mark
# 0    Anu   20    85
# 1   Binu   21    90
# 2  Cathy   22    70

# %%
import pandas as pd
data={
    'name':['Anu','Binu','Cathy','David','Eva'],
    'mark':[85,90,78,88,95],

}

df=pd.DataFrame(data)
print("Head:")
print(df.head())
print("\ntail:")
print(df.tail())
# Out:
# Head:
#     name  mark
# 0    Anu    85
# 1   Binu    90
# 2  Cathy    78
# 3  David    88
# 4    Eva    95
#
# tail:
#     name  mark
# 0    Anu    85
# 1   Binu    90
# 2  Cathy    78
# 3  David    88
# 4    Eva    95
